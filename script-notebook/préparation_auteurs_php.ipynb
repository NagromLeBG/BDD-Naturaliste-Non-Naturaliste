# %% [markdown]
# # Import des bibliothèques nécessaires pour la connexion à la base de données et l'exécution de requêtes SQL
#
# `import mysql.connector`
#
# `import os`
#
# `from dotenv import load_dotenv`
#
# `from mysql.connector import Error`

# %%
import mysql.connector
import os
from mysql.connector import Error
from dotenv import load_dotenv

# %% [markdown]
# # Vérification de la connexion à la base de données

# %% [markdown]
# - pour la vérification de la connexion à la base de données je vais utiliser la fonction `get_db_connection()` pour vérifier ma liste d'auteurs.

# %%
load_dotenv()

def get_db_connection():
    """Établit et retourne la connexion à la base de données MySQL."""
    try:
        conn = mysql.connector.connect(
            host=os.getenv("DB_HOST"),
            user=os.getenv("DB_USER"),
            port=os.getenv("DB_PORT"),
            password=os.getenv("DB_PASSWORD"),
            database=os.getenv("DB_NAME")
        )
        if conn.is_connected():
            print("Connexion réussie à la base de données !")
            return conn
    except Error as e:
        print(f"Erreur lors de la connexion à MySQL : {e}")
        return None
    
    
ma_connexion = get_db_connection()

# Requête SQL pour récupérer tous les informations de la table `auteurs`
requete = """
        SELECT * FROM auteurs
        """

if ma_connexion is not None:
    try:
        # On utilise la variable qui contient la connexion valide
        cursor = ma_connexion.cursor()
        
        cursor.execute(requete)
        lignes = cursor.fetchall()
        print(f"{len(lignes)} auteurs trouvés :")
        for ligne in lignes:
            print(ligne)
            
    except Error as e:
        print(f"Erreur lors de l'exécution de la requête : {e}")
        
    finally:
        # On ferme la connexion à la base de données
        cursor.close()
        ma_connexion.close()
        print("Connexion fermée ")
else:
    print("Script arrêté : Impossible de se connecter à la base.")
# Out:
# Connexion réussie à la base de données !
# 48 auteurs trouvés :
# (1, 'de Goncourt', 'Edmond', 1822, 1896)
# (2, 'de Goncourt', 'Jules', 1830, 1870)
# (3, 'Zola', 'Émile', 1840, 1902)
# (4, 'Flaubert', 'Gustave', 1821, 1880)
# (5, 'Daudet', 'Alphonse', 1840, 1897)
# (6, 'Kock', 'Paul de', 1793, 1871)
# (7, 'Adam', 'Paul', 1862, 1920)
# (8, 'Albalat', 'Antoine', 1856, 1935)
# (9, 'Alis', 'Harry', 1857, 1895)
# (10, "Barbey d'Aurevilly ", 'Jules', 1808, 1889)
# (11, 'Bonnetain', 'Paul', 1858, 1899)
# (12, 'Caze', 'Robert', 1853, 1886)
# (13, 'Céard', 'Henry', 1851, 1924)
# (14, 'Cherbuliez', 'Victor', 1829, 1899)
# (15, 'Cladel', 'Léon', 1834, 1892)
# (16, 'Cleretie', 'Jules', 1840, 1913)
# (17, 'Debans', 'Camille', 1832, 1919)
# (18, 'Dubut de Laforest', 'Jean-Louis', 1853, 1902)
# (19, 'Enne', 'Francis', 1844, 1891)
# (20, 'Greville', 'Henry', 1842, 1902)
# (21, 'Hennique', 'Léon', 1850, 1935)
# (22, 'Huysmans', 'Joris-Karl', 1848, 1907)
# (23, 'Lemmonier', 'Camille', 1844, 1913)
# (24, 'Lesueur', 'Daniel', 1854, 1921)
# (25, 'Margueritte', 'Paul', 1860, 1918)
# (26, ' de Maupassant', 'Guy', 1850, 1893)
# (27, 'Mérouvel', 'Charles', 1832, 1920)
# (28, 'Méténier', 'Oscar', 1859, 1913)
# (29, 'Ohnet', 'Georges', 1848, 1918)
# (30, 'Perret', 'Paul', 1830, 1904)
# (31, 'Eymery', 'Marguerite', 1860, 1953)
# (32, 'Rod', 'Édouard', 1857, 1910)
# (33, 'Rosny', 'Joseph Henri ', 1856, 1940)
# (34, 'Valles', 'Jules', 1832, 1885)
# (35, 'Verne', 'Jules', 1828, 1905)
# (36, 'Alexis', 'Paul', 1847, 1901)
# (37, 'Bloy', 'Léon', 1846, 1917)
# (38, 'Bourget', 'Paul', 1852, 1935)
# (39, 'Coppée', 'François', 1842, 1908)
# (40, 'Courteline', 'Georges', 1858, 1929)
# (41, 'Descaves', 'Lucien', 1861, 1949)
# (42, 'Eekhoud', 'Georges', 1854, 1927)
# (43, 'France', 'Anatole', 1844, 1924)
# (44, 'Guiches', 'Gustaves', 1860, 1935)
# (45, 'Hervieu', 'Paul', 1857, 1915)
# (46, 'de Stolz', 'Madame', 1820, 1892)
# (47, 'André', 'Theuriet', 1833, 1907)
# (48, 'Villiers', 'Auguste', 1838, 1889)
# Connexion fermée

# %% [markdown]
# # création de l'auteur avec ses romans

# %%
# Pour la connection a la base de données:
load_dotenv()
def get_db_connection():
    """Établit et retourne la connexion à la base de données MySQL."""
    try:
        conn = mysql.connector.connect(
            host=os.getenv("DB_HOST"),
            user=os.getenv("DB_USER"),
            port=os.getenv("DB_PORT"),
            password=os.getenv("DB_PASSWORD"),
            database=os.getenv("DB_NAME")
        )
        if conn.is_connected():
            print("Connexion réussie à la base de données !")
            return conn

    except Error as e:
        print(f"Erreur lors de la connexion à MySQL : {e}")
        return None


connexion = get_db_connection()

requete = """
       INSERT INTO auteurs (nom, prenom, date_naissance, date_mort)
        VALUES ("Villiers", 'Auguste', 1838 , 1889);        
        """
        
if connexion is not None:
    try:
        # On utilise la variable qui contient la connexion valide
        cursor = connexion.cursor()
        
        cursor.execute(requete)
        connexion.commit()
        print("Auteur ajouté avec succès")
    except Error as e:
        print(f"Erreur lors de l'exécution de la requête : {e}")
        
    finally:
        # On ferme la connexion à la base de données
        cursor.close()
        connexion.close()
        print("Connexion fermée ")
else:
    print("Script arrêté : Impossible de se connecter à la base.")
# Out:
# Connexion réussie à la base de données !
# Auteur ajouté avec succès
# Connexion fermée

# %% [markdown]
# # Ajout des romans de l'auteur dans la base de données

# %%
# Pour la connection a la base de données:
load_dotenv()
def get_db_connection():
    """Établit et retourne la connexion à la base de données MySQL."""
    try:
        conn = mysql.connector.connect(
            host=os.getenv("DB_HOST"),
            user=os.getenv("DB_USER"),
            port=os.getenv("DB_PORT"),
            password=os.getenv("DB_PASSWORD"),
            database=os.getenv("DB_NAME")
        )
        if conn.is_connected():
            print("Connexion réussie à la base de données !")
            return conn

    except Error as e:
        print(f"Erreur lors de la connexion à MySQL : {e}")
        return None

connexion = get_db_connection()

requete = """
    INSERT INTO romans (titre, annee_publication) 
    VALUES
    ("L'Ève future", 1886);
    """      
              
if connexion is not None:
    try:
        # On utilise la variable qui contient la connexion valide
        cursor = connexion.cursor()
        
        cursor.execute(requete)
        connexion.commit()
        print("Romans ajouté avec succès")
    except Error as e:
        print(f"Erreur lors de l'exécution de la requête : {e}")
        
    finally:
        # On ferme la connexion à la base de données
        cursor.close()
        connexion.close()
        print("Connexion fermée ")
else:
    print("Script arrêté : Impossible de se connecter à la base.")
# Out:
# Connexion réussie à la base de données !
# Romans ajouté avec succès
# Connexion fermée

# %% [markdown]
# # Relier `'id_roman` à l'id de l'auteur dans la table `auteurs_romans`

# %%
# Pour la connection a la base de données:
load_dotenv()
def get_db_connection():
    """Établit et retourne la connexion à la base de données MySQL."""
    try:
        conn = mysql.connector.connect(
            host=os.getenv("DB_HOST"),
            user=os.getenv("DB_USER"),
            port=os.getenv("DB_PORT"),
            password=os.getenv("DB_PASSWORD"),
            database=os.getenv("DB_NAME")
        )
        if conn.is_connected():
            print("Connexion réussie à la base de données !")
            return conn

    except Error as e:
        print(f"Erreur lors de la connexion à MySQL : {e}")
        return None

connexion = get_db_connection()

requete = """
INSERT INTO auteurs_romans (id_auteur, id_roman) 
VALUES
(48, 117);    
"""      
              
if connexion is not None:
    try:
        # On utilise la variable qui contient la connexion valide
        cursor = connexion.cursor()
        
        cursor.execute(requete)
        connexion.commit()
        print("Romans relies à l'auteur avec succès")
    except Error as e:
        print(f"Erreur lors de l'exécution de la requête : {e}")
        
    finally:
        # On ferme la connexion à la base de données
        cursor.close()
        connexion.close()
        print("Connexion fermée ")
else:
    print("Script arrêté : Impossible de se connecter à la base.")
# Out:
# Connexion réussie à la base de données !
# Romans relies à l'auteur avec succès
# Connexion fermée
