# %%
import mysql.connector

# Connexion à MySQL
connexion = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="romans_nlp"
)

cursor = connexion.cursor()

# Chemin vers ton fichier texte
chemin_fichier = r""

# Titre du roman déjà présent dans la table romans
titre_roman = 

# Lire le fichier texte
with open(chemin_fichier, "r", encoding="utf-8") as f:
    texte = f.read()

# Mettre à jour la colonne texte_brut
requete = """
UPDATE romans
SET texte_brut = %s
WHERE titre = %s
"""

cursor.execute(requete, (texte, titre_roman))
connexion.commit()

print("Texte brut ajouté avec succès.")

cursor.close()
connexion.close()
# Out:
# Texte brut ajouté avec succès.
